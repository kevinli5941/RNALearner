# %% [markdown]
# ## Preprocesses Downstream Datasets
#
# E.g. OSD-105
#
# **Note:** To make the dataset scBERT ready, you must then run `preprocessing.py` (which is in the base RNALearner directory) AFTER running the code in this file, using the output dataset of this file as the input dataset in `preprocessing.py`.

# %% [markdown]
# ### To AnnData Object

# %%
import pandas as pd
import numpy as np
import scanpy as sc

# %%
#data = pd.read_csv("osd105/GLDS-105_rna_seq_Unnormalized_Counts.csv")
data = pd.read_csv("osd99/GLDS-99_rna_seq_Unnormalized_Counts.csv")
data = data.set_index("Unnamed: 0")
data
# Out:
#                     Mmus_C57-6J_EDL_FLT_Rep1_M23  \
# Unnamed: 0
# ENSMUSG00000000001                         909.0
# ENSMUSG00000000003                           0.0
# ENSMUSG00000000028                          90.0
# ENSMUSG00000000031                       26779.0
# ENSMUSG00000000037                           4.0
# ...                                          ...
# ENSMUSG00000118389                           0.0
# ENSMUSG00000118390                           0.0
# ENSMUSG00000118391                           0.0
# ENSMUSG00000118392                           0.0
# ENSMUSG00000118393                           0.0
#
#                     Mmus_C57-6J_EDL_FLT_Rep2_M26  \
# Unnamed: 0
# ENSMUSG00000000001                        1408.0
# ENSMUSG00000000003                           0.0
# ENSMUSG00000000028                         180.0
# ENSMUSG00000000031                       42757.0
# ENSMUSG00000000037                           9.0
# ...                                          ...
# ENSMUSG00000118389                           0.0
# ENSMUSG00000118390                           0.0
# ENSMUSG00000118391                           0.0
# ENSMUSG00000118392                           0.0
# ENSMUSG00000118393                           0.0
#
#                     Mmus_C57-6J_EDL_FLT_Rep3_M27  \
# Unnamed: 0
# ENSMUSG00000000001                        1421.0
# ENSMUSG00000000003                           0.0
# ENSMUSG00000000028                         232.0
# ENSMUSG00000000031                       24304.0
# ENSMUSG00000000037                           8.0
# ...                                          ...
# ENSMUSG00000118389                           0.0
# ENSMUSG00000118390                           0.0
# ENSMUSG00000118391                           0.0
# ENSMUSG00000118392                           0.0
# ENSMUSG00000118393                           0.0
#
#                     Mmus_C57-6J_EDL_FLT_Rep4_M28  \
# Unnamed: 0
# ENSMUSG00000000001                        1444.0
# ENSMUSG00000000003                           0.0
# ENSMUSG00000000028                         126.0
# ENSMUSG00000000031                       31095.0
# ENSMUSG00000000037                           8.0
# ...                                          ...
# ENSMUSG00000118389                           0.0
# ENSMUSG00000118390                           0.0
# ENSMUSG00000118391                           0.0
# ENSMUSG00000118392                           0.0
# ENSMUSG00000118393                           0.0
#
#                     Mmus_C57-6J_EDL_FLT_Rep5_M29  \
# Unnamed: 0
# ENSMUSG00000000001                        1508.0
# ENSMUSG00000000003                           0.0
# ENSMUSG00000000028                         154.0
# ENSMUSG00000000031                       30104.0
# ENSMUSG00000000037                          14.0
# ...                                          ...
# ENSMUSG00000118389                           0.0
# ENSMUSG00000118390                           0.0
# ENSMUSG00000118391                           0.0
# ENSMUSG00000118392                           0.0
# ENSMUSG00000118393                           0.0
#
#                     Mmus_C57-6J_EDL_FLT_Rep6_M30  Mmus_C57-6J_EDL_GC_Rep1_M31  \
# Unnamed: 0
# ENSMUSG00000000001                        1413.0                       1339.0
# ENSMUSG00000000003                           0.0                          0.0
# ENSMUSG00000000028                         149.0                        161.0
# ENSMUSG00000000031                       31753.0                      38976.0
# ENSMUSG00000000037                           8.0                         14.0
# ...                                          ...                          ...
# ENSMUSG00000118389                           0.0                          0.0
# ENSMUSG00000118390                           0.0                          0.0
# ENSMUSG00000118391                           0.0                          0.0
# ENSMUSG00000118392                           0.0                          0.0
# ENSMUSG00000118393                           0.0                          0.0
#
#                     Mmus_C57-6J_EDL_GC_Rep2_M32  Mmus_C57-6J_EDL_GC_Rep3_M37  \
# Unnamed: 0
# ENSMUSG00000000001                       1026.0                       1058.0
# ENSMUSG00000000003                          0.0                          0.0
# ENSMUSG00000000028                        159.0                        150.0
# ENSMUSG00000000031                      21904.0                      34635.0
# ENSMUSG00000000037                          6.0                          5.0
# ...                                         ...                          ...
# ENSMUSG00000118389                          0.0                          0.0
# ENSMUSG00000118390                          0.0                          0.0
# ENSMUSG00000118391                          0.0                          0.0
# ENSMUSG00000118392                          0.0                          0.0
# ENSMUSG00000118393                          0.0                          0.0
#
#                     Mmus_C57-6J_EDL_GC_Rep4_M38  Mmus_C57-6J_EDL_GC_Rep5_M39  \
# Unnamed: 0
# ENSMUSG00000000001                       1207.0                       1160.0
# ENSMUSG00000000003                          0.0                          0.0
# ENSMUSG00000000028                        173.0                        146.0
# ENSMUSG00000000031                      29431.0                      32538.0
# ENSMUSG00000000037                          9.0                          7.0
# ...                                         ...                          ...
# ENSMUSG00000118389                          0.0                          0.0
# ENSMUSG00000118390                          0.0                          0.0
# ENSMUSG00000118391                          0.0                          0.0
# ENSMUSG00000118392                          0.0                          0.0
# ENSMUSG00000118393                          0.0                          0.0
#
#                     Mmus_C57-6J_EDL_GC_Rep6_M40
# Unnamed: 0
# ENSMUSG00000000001                       1133.0
# ENSMUSG00000000003                          0.0
# ENSMUSG00000000028                        177.0
# ENSMUSG00000000031                      31259.0
# ENSMUSG00000000037                          8.0
# ...                                         ...
# ENSMUSG00000118389                          0.0
# ENSMUSG00000118390                          0.0
# ENSMUSG00000118391                          0.0
# ENSMUSG00000118392                          0.0
# ENSMUSG00000118393                          0.0
#
# [55536 rows x 12 columns]

# %%
adata = sc.AnnData(data.T, data.columns.to_frame(), data.index.to_frame())
adata.obs.columns = ['Sample ID']
adata.var.columns = ['Gene ID']
adata.var
# Out:
# /tmp/ipykernel_374168/663925404.py:1: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = sc.AnnData(data.T, data.columns.to_frame(), data.index.to_frame())

# %% [markdown]
# ### Ensembl to Gene ID

# %%
import pybiomart
import numpy as np

# %%
dataset = pybiomart.Dataset(name='mmusculus_gene_ensembl', host='http://www.ensembl.org')
mappings = dataset.query(attributes=['ensembl_gene_id', 'external_gene_name'])

# %%
def convert(e):
    x = mappings[mappings['Gene stable ID'] == e]
    if x.shape[0] != 0:
        return x['Gene name'].iloc[0]
    return np.NaN
gene_ids = adata.var_names.str.slice(stop=18).map(convert)
gene_ids
# Out:
# Index([        'Gnai3',          'Pbsn',         'Cdc45',           'H19',
#                'Scml2',          'Apoh',          'Narf',          'Cav2',
#                 'Klf6',         'Scmh1',
#        ...
#        '9030625G05Rik',       'Gm50311',       'Gm50149',       'Gm50415',
#              'Vmn1r64',       'Gm50246',       'Gm50102',       'Gm19519',
#        '4930524O05Rik',       'Gm50426'],
#       dtype='object', name='Unnamed: 0', length=55536)

# %%
adata.var_names = gene_ids
adata.var.index = adata.var_names.fillna("No GeneID")

# %%
# Assign labels for the downstream dataset. 
# This part depends on what your downstream dataset is and whether or not it includes labels 
# in the data table already.
adata.obs["y"] = ["FLT"] * 6 + ["GC"] * 6

# %%
adata.var
# Out:
#                           Gene ID
# Unnamed: 0
# Gnai3          ENSMUSG00000000001
# Pbsn           ENSMUSG00000000003
# Cdc45          ENSMUSG00000000028
# H19            ENSMUSG00000000031
# Scml2          ENSMUSG00000000037
# ...                           ...
# Gm50246        ENSMUSG00000118389
# Gm50102        ENSMUSG00000118390
# Gm19519        ENSMUSG00000118391
# 4930524O05Rik  ENSMUSG00000118392
# Gm50426        ENSMUSG00000118393
#
# [55536 rows x 1 columns]

# %%
adata.obs
# Out:
#                                                  Sample ID    y
# Mmus_C57-6J_EDL_FLT_Rep1_M23  Mmus_C57-6J_EDL_FLT_Rep1_M23  FLT
# Mmus_C57-6J_EDL_FLT_Rep2_M26  Mmus_C57-6J_EDL_FLT_Rep2_M26  FLT
# Mmus_C57-6J_EDL_FLT_Rep3_M27  Mmus_C57-6J_EDL_FLT_Rep3_M27  FLT
# Mmus_C57-6J_EDL_FLT_Rep4_M28  Mmus_C57-6J_EDL_FLT_Rep4_M28  FLT
# Mmus_C57-6J_EDL_FLT_Rep5_M29  Mmus_C57-6J_EDL_FLT_Rep5_M29  FLT
# Mmus_C57-6J_EDL_FLT_Rep6_M30  Mmus_C57-6J_EDL_FLT_Rep6_M30  FLT
# Mmus_C57-6J_EDL_GC_Rep1_M31    Mmus_C57-6J_EDL_GC_Rep1_M31   GC
# Mmus_C57-6J_EDL_GC_Rep2_M32    Mmus_C57-6J_EDL_GC_Rep2_M32   GC
# Mmus_C57-6J_EDL_GC_Rep3_M37    Mmus_C57-6J_EDL_GC_Rep3_M37   GC
# Mmus_C57-6J_EDL_GC_Rep4_M38    Mmus_C57-6J_EDL_GC_Rep4_M38   GC
# Mmus_C57-6J_EDL_GC_Rep5_M39    Mmus_C57-6J_EDL_GC_Rep5_M39   GC
# Mmus_C57-6J_EDL_GC_Rep6_M40    Mmus_C57-6J_EDL_GC_Rep6_M40   GC

# %%
adata.obs_names = adata.obs_names.str.split("_").str[-1]

# %%
adata.var.index = adata.var.index.str.lower()

# %%
adata.var
# Out:
#                           Gene ID
# Unnamed: 0
# gnai3          ENSMUSG00000000001
# pbsn           ENSMUSG00000000003
# cdc45          ENSMUSG00000000028
# h19            ENSMUSG00000000031
# scml2          ENSMUSG00000000037
# ...                           ...
# gm50246        ENSMUSG00000118389
# gm50102        ENSMUSG00000118390
# gm19519        ENSMUSG00000118391
# 4930524o05rik  ENSMUSG00000118392
# gm50426        ENSMUSG00000118393
#
# [55536 rows x 1 columns]

# %%
#adata.write_h5ad("osd105/osd105_raw_ensembl_all_genes.h5ad")
adata.write_h5ad("osd99/osd99_raw_ensembl_all_genes.h5ad")
