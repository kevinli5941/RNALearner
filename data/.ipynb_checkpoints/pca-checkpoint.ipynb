# %%
import pandas as pd
import h5py
import scanpy as sc
from scipy import sparse
import pybiomart
import numpy as np

# %%
data = sc.read_h5ad('recount3/mouse_FULL_sparse_with_geneIDs_with_metadata.h5ad')
# Out:
# /home/kli3/.conda/envs/scbert/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
data_dense = data.X.todense()

# %%
data.var['Ensemble ID']
# Out:
# NO GENEID    ENSMUSG00000079800.2
# NO GENEID    ENSMUSG00000095092.1
# NO GENEID    ENSMUSG00000079192.2
# NO GENEID    ENSMUSG00000079794.2
# NO GENEID    ENSMUSG00000094799.1
#                      ...
# MID1-PS1     ENSMUSG00000095134.2
# GM47283      ENSMUSG00000096768.8
# GM21748      ENSMUSG00000096850.1
# GM21742      ENSMUSG00000099871.1
# NO GENEID                 project
# Name: Ensemble ID, Length: 55422, dtype: object

# %%
data_dense_df = pd.DataFrame(data_dense)
data_dense_df.columns = data.var['Ensemble ID']
data_dense_df.index = data.obs["Sample ID"]
data_dense_df["study"] = data.obs["Sample ID"]
data_dense_df['pattern.predict.type'] = data.obs["pattern.predict.type"]

# %%
data_dense_df
# Out:
# Ensemble ID  ENSMUSG00000079800.2  ENSMUSG00000095092.1  ENSMUSG00000079192.2  \
# Sample ID
# SRR8249400                    0.0                   0.0                   0.0
# SRR8249500                    0.0                   0.0                   0.0
# SRR8249300                    0.0                   0.0                   0.0
# SRR8249200                    0.0                   0.0                   0.0
# SRR8249401                    0.0                   0.0                   0.0
# ...                           ...                   ...                   ...
# SRR5445513                  767.0                   0.0                 281.0
# SRR5445514                 1628.0                 106.0                1887.0
# SRR5445515                 1068.0                   0.0                1241.0
# SRR5445516                  464.0                   0.0                1221.0
# SRR5445517                 2372.0                   0.0                2706.0
#
# Ensemble ID  ENSMUSG00000079794.2  ENSMUSG00000094799.1  ENSMUSG00000095250.1  \
# Sample ID
# SRR8249400                    0.0                   0.0                   0.0
# SRR8249500                    0.0                   0.0                   0.0
# SRR8249300                    0.0                   0.0                   0.0
# SRR8249200                    0.0                   0.0                   0.0
# SRR8249401                    0.0                   0.0                   0.0
# ...                           ...                   ...                   ...
# SRR5445513                    0.0                  78.0                 253.0
# SRR5445514                  227.0                  88.0                1275.0
# SRR5445515                   80.0                   0.0                 693.0
# SRR5445516                    0.0                   0.0                 559.0
# SRR5445517                   96.0                 187.0                2163.0
#
# Ensemble ID  ENSMUSG00000095787.1  ENSMUSG00000096100.1  ENSMUSG00000094054.1  \
# Sample ID
# SRR8249400                    0.0                   0.0                   0.0
# SRR8249500                    0.0                   0.0                   0.0
# SRR8249300                    0.0                   0.0                   0.0
# SRR8249200                    0.0                   0.0                   0.0
# SRR8249401                    0.0                   0.0                   0.0
# ...                           ...                   ...                   ...
# SRR5445513                 1026.0                 591.0                   0.0
# SRR5445514                 1411.0                2477.0                 197.0
# SRR5445515                 1424.0                1072.0                   0.0
# SRR5445516                  810.0                 545.0                   0.0
# SRR5445517                 1751.0                 814.0                   0.0
#
# Ensemble ID  ENSMUSG00000095672.1  ...  ENSMUSG00000099619.6  \
# Sample ID                          ...
# SRR8249400                    0.0  ...                   0.0
# SRR8249500                    0.0  ...                   0.0
# SRR8249300                    0.0  ...                   0.0
# SRR8249200                    0.0  ...                   0.0
# SRR8249401                    0.0  ...                   0.0
# ...                           ...  ...                   ...
# SRR5445513                  152.0  ...                   0.0
# SRR5445514                 1190.0  ...                   0.0
# SRR5445515                  586.0  ...                   0.0
# SRR5445516                  285.0  ...                   0.0
# SRR5445517                 1584.0  ...                   0.0
#
# Ensemble ID  ENSMUSG00000099399.6  ENSMUSG00000095366.2  ENSMUSG00000095134.2  \
# Sample ID
# SRR8249400                    0.0                 316.0                 130.0
# SRR8249500                    0.0                   0.0                   0.0
# SRR8249300                    0.0                 300.0                   0.0
# SRR8249200                    0.0                   0.0                   0.0
# SRR8249401                    0.0                   0.0                   0.0
# ...                           ...                   ...                   ...
# SRR5445513                    0.0                   0.0                   0.0
# SRR5445514                    0.0                 198.0                 100.0
# SRR5445515                    0.0                 471.0                  88.0
# SRR5445516                    0.0                 198.0                   0.0
# SRR5445517                    0.0                 635.0                 295.0
#
# Ensemble ID  ENSMUSG00000096768.8  ENSMUSG00000096850.1  ENSMUSG00000099871.1  \
# Sample ID
# SRR8249400                13959.0                   0.0                  75.0
# SRR8249500                 9486.0                   0.0                   0.0
# SRR8249300                 8672.0                   0.0                   0.0
# SRR8249200                    0.0                   0.0                   0.0
# SRR8249401                    0.0                   0.0                   0.0
# ...                           ...                   ...                   ...
# SRR5445513                14752.0                   0.0                   0.0
# SRR5445514                34878.0                 178.0                   0.0
# SRR5445515                 7221.0                  53.0                   0.0
# SRR5445516                 6559.0                   0.0                   0.0
# SRR5445517                18282.0                   0.0                   0.0
#
# Ensemble ID  project       study  pattern.predict.type
# Sample ID
# SRR8249400       0.0  SRR8249400             scrna-seq
# SRR8249500       0.0  SRR8249500             scrna-seq
# SRR8249300       0.0  SRR8249300             scrna-seq
# SRR8249200       0.0  SRR8249200             scrna-seq
# SRR8249401       0.0  SRR8249401             scrna-seq
# ...              ...         ...                   ...
# SRR5445513   10087.0  SRR5445513               rna-seq
# SRR5445514   10087.0  SRR5445514               rna-seq
# SRR5445515   10087.0  SRR5445515               rna-seq
# SRR5445516   10087.0  SRR5445516               rna-seq
# SRR5445517   10087.0  SRR5445517               rna-seq
#
# [416803 rows x 55424 columns]

# %%
data_sc = data_dense_df[data_dense_df["pattern.predict.type"] == "scrna-seq"]
data_bulk = data_dense_df[data_dense_df["pattern.predict.type"] == "rna-seq"]

# %%
data_preprocessed = sc.read_h5ad('recount3/preprocessed_data_with_metadata_2_8.h5ad')
# Out:
# /home/kli3/.conda/envs/scbert/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
data_preprocessed_dense = data_preprocessed.X.todense()

# %%
data_preprocessed_dense_df = pd.DataFrame(data_preprocessed_dense)
data_preprocessed_dense_df.columns = data_preprocessed.var['Ensemble ID']
data_preprocessed_dense_df.index = data_preprocessed.obs["Sample ID"]
data_preprocessed_dense_df["study"] = data_preprocessed.obs["Sample ID"]
data_preprocessed_dense_df['pattern.predict.type'] = data_preprocessed.obs["pattern.predict.type"]

# %%
data_preprocessed_dense_df
# Out:
# Ensemble ID  ENSMUSG00000079800.2  ENSMUSG00000095092.1  ENSMUSG00000079192.2  \
# Sample ID
# SRR8249400               0.000000               0.00000              0.000000
# SRR8249500               0.000000               0.00000              0.000000
# SRR8249300               0.000000               0.00000              0.000000
# SRR8249200               0.000000               0.00000              0.000000
# SRR8249401               0.000000               0.00000              0.000000
# ...                           ...                   ...                   ...
# SRR5445513               0.028161               0.00000              0.010381
# SRR5445514               0.022260               0.00146              0.025770
# SRR5445515               0.021291               0.00000              0.024711
# SRR5445516               0.016178               0.00000              0.042190
# SRR5445517               0.025859               0.00000              0.029463
#
# Ensemble ID  ENSMUSG00000079794.2  ENSMUSG00000094799.1  ENSMUSG00000095250.1  \
# Sample ID
# SRR8249400               0.000000              0.000000              0.000000
# SRR8249500               0.000000              0.000000              0.000000
# SRR8249300               0.000000              0.000000              0.000000
# SRR8249200               0.000000              0.000000              0.000000
# SRR8249401               0.000000              0.000000              0.000000
# ...                           ...                   ...                   ...
# SRR5445513               0.000000              0.002889              0.009350
# SRR5445514               0.003125              0.001212              0.017463
# SRR5445515               0.001606              0.000000              0.013851
# SRR5445516               0.000000              0.000000              0.019469
# SRR5445517               0.001056              0.002056              0.023599
#
# Ensemble ID  ENSMUSG00000095787.1  ENSMUSG00000096100.1  ENSMUSG00000094054.1  \
# Sample ID
# SRR8249400               0.000000              0.000000              0.000000
# SRR8249500               0.000000              0.000000              0.000000
# SRR8249300               0.000000              0.000000              0.000000
# SRR8249200               0.000000              0.000000              0.000000
# SRR8249401               0.000000              0.000000              0.000000
# ...                           ...                   ...                   ...
# SRR5445513               0.037548              0.021748              0.000000
# SRR5445514               0.019313              0.033734              0.002712
# SRR5445515               0.028319              0.021370              0.000000
# SRR5445516               0.028126              0.018984              0.000000
# SRR5445517               0.019133              0.008926              0.000000
#
# Ensemble ID  ENSMUSG00000095672.1  ...  ENSMUSG00000099619.6  \
# Sample ID                          ...
# SRR8249400               0.000000  ...                   0.0
# SRR8249500               0.000000  ...                   0.0
# SRR8249300               0.000000  ...                   0.0
# SRR8249200               0.000000  ...                   0.0
# SRR8249401               0.000000  ...                   0.0
# ...                           ...  ...                   ...
# SRR5445513               0.005625  ...                   0.0
# SRR5445514               0.016305  ...                   0.0
# SRR5445515               0.011721  ...                   0.0
# SRR5445516               0.009959  ...                   0.0
# SRR5445517               0.017319  ...                   0.0
#
# Ensemble ID  ENSMUSG00000099399.6  ENSMUSG00000095366.2  ENSMUSG00000095134.2  \
# Sample ID
# SRR8249400                    0.0              0.009873              0.004070
# SRR8249500                    0.0              0.000000              0.000000
# SRR8249300                    0.0              0.012547              0.000000
# SRR8249200                    0.0              0.000000              0.000000
# SRR8249401                    0.0              0.000000              0.000000
# ...                           ...                   ...                   ...
# SRR5445513                    0.0              0.000000              0.000000
# SRR5445514                    0.0              0.002726              0.001377
# SRR5445515                    0.0              0.009428              0.001766
# SRR5445516                    0.0              0.006926              0.000000
# SRR5445517                    0.0              0.006968              0.003241
#
# Ensemble ID  ENSMUSG00000096768.8  ENSMUSG00000096850.1  ENSMUSG00000099871.1  \
# Sample ID
# SRR8249400               0.382206              0.000000              0.002349
# SRR8249500               0.331776              0.000000              0.000000
# SRR8249300               0.324801              0.000000              0.000000
# SRR8249200               0.000000              0.000000              0.000000
# SRR8249401               0.000000              0.000000              0.000000
# ...                           ...                   ...                   ...
# SRR5445513               0.463749              0.000000              0.000000
# SRR5445514               0.414815              0.002451              0.000000
# SRR5445515               0.138188              0.001064              0.000000
# SRR5445516               0.213393              0.000000              0.000000
# SRR5445517               0.188265              0.000000              0.000000
#
# Ensemble ID   project       study  pattern.predict.type
# Sample ID
# SRR8249400   0.000000  SRR8249400             scrna-seq
# SRR8249500   0.000000  SRR8249500             scrna-seq
# SRR8249300   0.000000  SRR8249300             scrna-seq
# SRR8249200   0.000000  SRR8249200             scrna-seq
# SRR8249401   0.000000  SRR8249401             scrna-seq
# ...               ...         ...                   ...
# SRR5445513   0.332545  SRR5445513               rna-seq
# SRR5445514   0.132699  SRR5445514               rna-seq
# SRR5445515   0.189564  SRR5445515               rna-seq
# SRR5445516   0.316328  SRR5445516               rna-seq
# SRR5445517   0.106896  SRR5445517               rna-seq
#
# [410235 rows x 55424 columns]

# %%
data_preprocessed_sc = data_preprocessed_dense_df[data_preprocessed_dense_df["pattern.predict.type"] == "scrna-seq"]
data_preprocessed_bulk = data_preprocessed_dense_df[data_preprocessed_dense_df["pattern.predict.type"] == "rna-seq"]

# %%
from sklearn.decomposition import PCA
pca_data = PCA(n_components=10)

# %%
X = pca_data.fit_transform(data_preprocessed_dense_df.iloc[:, :-3])

# %%
pca_data.explained_variance_ratio_
# Out:
# array([0.0904713 , 0.08059222, 0.04854373, 0.03335103, 0.03002617,
#        0.02461384, 0.01978958, 0.01562462, 0.01218334, 0.01051125])

# %%
X = pd.DataFrame(X)
X["project"] = list(data_preprocessed_dense_df["project"])
X["study"] = list(data_preprocessed_dense_df["study"])
X["pattern.predict.type"] = list(data_preprocessed_dense_df["pattern.predict.type"])

# %%
X
# Out:
#                 0          1          2         3          4          5  \
# 0      -25.370945 -22.029430   0.359480 -1.863398   8.123182   2.646901
# 1      -14.250147  -2.768531   5.426144  0.829574  13.700047  34.169628
# 2      -18.681072 -15.540974   3.297241  2.194621  14.430750   8.046741
# 3       -5.602170   6.071579   4.890025  2.009531   5.366101 -18.160440
# 4      -24.292894 -19.136087  -1.280149 -4.430531   0.139201   7.919092
# ...           ...        ...        ...       ...        ...        ...
# 410230  -4.782675  27.806475  15.873387 -7.870105  -5.944610   0.980152
# 410231  -4.258834  27.923943  15.833888 -7.992404  -5.470412   0.478693
# 410232  -9.913090  22.231321  17.152973 -4.449307 -10.076211   3.181969
# 410233  -9.890574  22.318653  17.148865 -4.446344 -10.095767   3.196132
# 410234  -9.717118  22.313358  17.106756 -4.436748 -10.066852   3.016366
#
#                 6          7         8          9   project       study  \
# 0        5.423393   6.127689  2.960064  -5.595279  0.000000  SRR8249400
# 1        0.929756  12.393850  1.941647 -14.870283  0.000000  SRR8249500
# 2        3.388597   5.515099 -1.959806  10.661134  0.000000  SRR8249300
# 3        3.566908   8.019548  1.223860  35.956211  0.000000  SRR8249200
# 4        6.468005   8.712089  3.064323 -10.182950  0.000000  SRR8249401
# ...           ...        ...       ...        ...       ...         ...
# 410230 -12.466521  -0.254206 -0.129453   4.638554  0.332545  SRR5445513
# 410231 -12.725702  -0.014929 -0.755588   5.253804  0.132699  SRR5445514
# 410232  -8.187683  -2.774056  1.838704  -0.837188  0.189564  SRR5445515
# 410233  -8.292650  -2.749212  1.837393  -0.914256  0.316328  SRR5445516
# 410234  -8.354518  -2.669578  1.207083  -0.573760  0.106896  SRR5445517
#
#        pattern.predict.type
# 0                 scrna-seq
# 1                 scrna-seq
# 2                 scrna-seq
# 3                 scrna-seq
# 4                 scrna-seq
# ...                     ...
# 410230              rna-seq
# 410231              rna-seq
# 410232              rna-seq
# 410233              rna-seq
# 410234              rna-seq
#
# [410235 rows x 13 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(X.iloc[0:500,:], hue="project", plot_kws = {'alpha': 0.1}, palette = "bright")

# %%
import pandas as pd

# %%
projects = pd.read_csv("projects.csv")

# %%
organism = 'human'
# organism = human

selected_projects = projects[projects['organism'] == organism]
selected_projects = selected_projects.reset_index()
n_proj = selected_projects.shape[0]
print("Total number of projects targeted: ", n_proj)
# Out:
# Total number of projects targeted:  8742

# %%
start = 5001 # start project for aggregation
end = 8001 # end project for aggregation
# end = n_proj - 1 # full run
print("Start: ", start)
print("End: ", end)
# Out:
# Start:  5001
# End:  8001

# %%
selected_projects['gene'][1]
# Out:
# 'http://idies.jhu.edu/recount3/data/human/data_sources/sra/gene_sums/65/SRP149665/sra.gene_sums.SRP149665.G026.gz'

# %%
http://idies.jhu.edu/recount3/data/human/data_sources/sra/gene_sums/65/SRP107565/sra.gene_sums.SRP107565.G026.gz
