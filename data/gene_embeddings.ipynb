# %%
import pandas as pd
import numpy as np

# %%
x = pd.read_csv("gene2vec/gene2vec_text.txt", sep="\s+", header = None)
x = x.set_index(0)
x
# Out:
#                    1         2         3         4         5         6    \
# 0
# PLAC4        -0.032111  0.005355 -0.001208  0.392700  0.027191  0.057858
# RPS2P45      -0.433589  0.383065  0.154259 -0.044726  0.406748  0.089424
# C3orf18       0.030009 -0.283322  0.213689  0.084640 -0.012634 -0.288767
# C6orf226      0.029573 -0.058847 -0.297716  0.257432  0.062723  0.071785
# CISD3         0.148815 -0.100394  0.139844 -0.156749 -0.000815  0.115267
# ...                ...       ...       ...       ...       ...       ...
# LOC284219    -0.097413  0.206977  0.274137 -0.052645 -0.163830  0.080587
# KRTAP21-1     0.093780 -0.661438  0.342262 -0.742463 -0.402170  0.172066
# PHBP8        -0.491280 -0.335584 -0.454166 -0.134393 -0.455670 -0.137623
# KCNE1L       -0.103615  0.133627 -0.156624  0.134105 -0.226790 -0.120270
# LOC101928725 -0.179048  0.241712 -0.074082 -0.137115  0.160695 -0.034816
#
#                    7         8         9         10   ...       191       192  \
# ...

# %%
np.load("gene2vec/gene2vec_16906.npy").shape
# Out:
# (16906, 200)

# %%
x.to_csv("gene2vec/gene2vec_FULL.csv")

# %%
x.to_numpy()
# Out:
# array([[-0.03211103,  0.00535526, -0.00120821, ..., -0.1831743 ,
#         -0.26482978,  0.10481831],
#        [-0.4335892 ,  0.38306454,  0.15425912, ...,  0.19937223,
#          0.10129236, -0.05468081],
#        [ 0.03000901, -0.28332168,  0.21368907, ..., -0.24634579,
#         -0.12093142,  0.15767238],
#        ...,
#        [-0.49127957, -0.33558366, -0.45416626, ..., -0.07114165,
#          0.02707783,  0.22366785],
#        [-0.10361467,  0.1336272 , -0.15662406, ...,  0.36187738,
#          0.19091946,  0.64915603],
#        [-0.1790477 ,  0.24171208, -0.07408224, ..., -0.10338113,
#         -0.30758673, -0.05300678]])

# %%
np.save("gene2vec/gene2vec_FULL.npy", x.to_numpy())

# %%
np.load("gene2vec/gene2vec_24447.npy")
# Out:
# array([[-0.03211103,  0.00535526, -0.00120821, ..., -0.1831743 ,
#         -0.26482978,  0.10481831],
#        [-0.4335892 ,  0.38306454,  0.15425912, ...,  0.19937223,
#          0.10129236, -0.05468081],
#        [ 0.03000901, -0.28332168,  0.21368907, ..., -0.24634579,
#         -0.12093142,  0.15767238],
#        ...,
#        [-0.49127957, -0.33558366, -0.45416626, ..., -0.07114165,
#          0.02707783,  0.22366785],
#        [-0.10361467,  0.1336272 , -0.15662406, ...,  0.36187738,
#          0.19091946,  0.64915603],
#        [-0.1790477 ,  0.24171208, -0.07408224, ..., -0.10338113,
#         -0.30758673, -0.05300678]])

# %%
pd.read_csv("gene2vec/gene2vec_24447.csv")
# Out:
#                   0         1         2         3         4         5  \
# 0             PLAC4 -0.032111  0.005355 -0.001208  0.392700  0.027191
# 1           RPS2P45 -0.433589  0.383065  0.154259 -0.044726  0.406748
# 2           C3orf18  0.030009 -0.283322  0.213689  0.084640 -0.012634
# 3          C6orf226  0.029573 -0.058847 -0.297716  0.257432  0.062723
# 4             CISD3  0.148815 -0.100394  0.139844 -0.156749 -0.000815
# ...             ...       ...       ...       ...       ...       ...
# 24442     LOC284219 -0.097413  0.206977  0.274137 -0.052645 -0.163830
# 24443     KRTAP21-1  0.093780 -0.661438  0.342262 -0.742463 -0.402170
# 24444         PHBP8 -0.491280 -0.335584 -0.454166 -0.134393 -0.455670
# 24445        KCNE1L -0.103615  0.133627 -0.156624  0.134105 -0.226790
# 24446  LOC101928725 -0.179048  0.241712 -0.074082 -0.137115  0.160695
#
#               6         7         8         9  ...       191       192  \
# ...

# %%
pd.read_csv("gene2vec/gene2vec_FULL.csv")
# Out:
#                   0         1         2         3         4         5  \
# 0             PLAC4 -0.032111  0.005355 -0.001208  0.392700  0.027191
# 1           RPS2P45 -0.433589  0.383065  0.154259 -0.044726  0.406748
# 2           C3orf18  0.030009 -0.283322  0.213689  0.084640 -0.012634
# 3          C6orf226  0.029573 -0.058847 -0.297716  0.257432  0.062723
# 4             CISD3  0.148815 -0.100394  0.139844 -0.156749 -0.000815
# ...             ...       ...       ...       ...       ...       ...
# 24442     LOC284219 -0.097413  0.206977  0.274137 -0.052645 -0.163830
# 24443     KRTAP21-1  0.093780 -0.661438  0.342262 -0.742463 -0.402170
# 24444         PHBP8 -0.491280 -0.335584 -0.454166 -0.134393 -0.455670
# 24445        KCNE1L -0.103615  0.133627 -0.156624  0.134105 -0.226790
# 24446  LOC101928725 -0.179048  0.241712 -0.074082 -0.137115  0.160695
#
#               6         7         8         9  ...       191       192  \
# ...
